# %% [markdown]
# # P5: Disaster Classification

# %%
# executive summary

# %%
# imports
# imports
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import patsy
from sqlalchemy import create_engine
import seaborn as sns
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Part 1: Aquire Data

# %% [markdown]
# To connect from terminal use:
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student titanic
#     password: gastudents

# %%
# connect to remote database
engine = create_engine('postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/titanic')

# %%
# query and aggregate
df = pd.read_sql('''SELECT
                "Embarked",
                "Survived",
                "Pclass",
                "Fare",
                "Sex",
                "Age",
                "SibSp",
                "Parch"
            FROM train''', engine)
df.head()
# Out:
#   Embarked  Survived  Pclass     Fare     Sex   Age  SibSp  Parch
# 0        S         0       3   7.2500    male  22.0      1      0
# 1        C         1       1  71.2833  female  38.0      1      0
# 2        S         1       3   7.9250  female  26.0      0      0
# 3        S         1       1  53.1000  female  35.0      1      0
# 4        S         0       3   8.0500    male  35.0      0      0

# %%
# # nulls, dups, recasts
df['Age'].fillna(round(df['Age'].mean()), inplace=True)
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
# risks and assumptions
# data dictionary

# %% [markdown]
# ## Part 2: Exploratory Data Analysis

# %%
df.info()

# %%
# describe data
#df.describe(include='all')

# %%
# visualize data
sns.heatmap(df.corr())

# %% [markdown]
# ## Part 3: Data Wrangling

# %%
# create dummy variables for Sex
#df = pd.concat([df, pd.get_dummies(df['Sex'])], axis=1); df

# %%
#df.drop('Sex', axis=1, inplace=True)

# %% [markdown]
# ## Part 4: Logistic Regression and Model Validation

# %%
from sklearn.cross_validation import train_test_split

# %%
# patsy our design matrix
y, X = patsy.dmatrices("Survived ~ C(Sex, Treatment(reference='male')) + C(Pclass) + Age + SibSp + Parch + C(Embarked)", data = df, return_type = 'dataframe')
#y, X = patsy.dmatrices("Survived ~ C(Sex, Treatment(reference='male')) + C(Pclass) + Age + SibSp + Parch + C(Embarked)", data = df, return_type = 'dataframe')

# %%
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size = .3, stratify=y, random_state = 42)

# %%
# ravel y for sklearn
y_ravel = y.values.ravel()

# %%
# fit model
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
logreg = LogisticRegression()
logreg.fit(Xtr, ytr)
logreg_pred = logreg.predict(Xte)
logreg.score(Xte, yte)
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.75862068965517238

# %%
# split and test generalization
logregCV = LogisticRegressionCV(cv=3)
logregCV.fit(Xtr, ytr)
print logregCV.score(Xte, yte)

# predict class labels
logregCV_pred = logregCV.predict(Xte)
# Out:
# 0.758620689655
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# classification report
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
target_names = ['dead', 'survived']
print classification_report(yte, logreg_pred, target_names=target_names)
print classification_report(yte, logregCV_pred, target_names=target_names)
# Out:
#              precision    recall  f1-score   support
#
#        dead       0.77      0.85      0.80       136
#    survived       0.74      0.64      0.69        96
#
# avg / total       0.76      0.76      0.76       232
#
#              precision    recall  f1-score   support
#
#        dead       0.75      0.88      0.81       136
#    survived       0.77      0.59      0.67        96
#
# avg / total       0.76      0.76      0.75       232

# %%
confusion_matrix(yte, logreg_pred)
# Out:
# array([[115,  21],
#        [ 35,  61]])

# %%
# classification report OLD
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
target_names = ['dead', 'survived']
print classification_report(yte, logreg_pred, target_names=target_names)
print classification_report(yte, logregCV_pred, target_names=target_names)
# Out:
#              precision    recall  f1-score   support
#
#        dead       0.77      0.85      0.80       136
#    survived       0.74      0.64      0.69        96
#
# avg / total       0.76      0.76      0.76       232
#
#              precision    recall  f1-score   support
#
#        dead       0.75      0.88      0.81       136
#    survived       0.77      0.59      0.67        96
#
# avg / total       0.76      0.76      0.75       232

# %%
cm = confusion_matrix(yte, logreg_pred)
pd.DataFrame(cm, index=target_names, columns=['predicted_'+x for x in target_names])
# Out:
#           predicted_dead  predicted_survived
# dead                 115                  21
# survived              35                  61

# %%
cm = confusion_matrix(yte, logregCV_pred)
pd.DataFrame(cm, index=target_names, columns=['predicted_'+x for x in target_names])
# Out:
#           predicted_dead  predicted_survived
# dead                 115                  12
# survived              32                  55

# %%
coefDf = pd.DataFrame(list(zip(X.columns, np.transpose(logreg.coef_))))
#print 'Model Coefficients: \n', 
coefDf
# Out:
#                                                0                   1
# 0                                      Intercept    [0.685562127751]
# 1  C(Sex, Treatment(reference='male'))[T.female]     [2.42112815892]
# 2                                 C(Pclass)[T.2]   [-0.893819176841]
# 3                                 C(Pclass)[T.3]    [-2.20684767208]
# 4                               C(Embarked)[T.Q]   [-0.601778017798]
# 5                               C(Embarked)[T.S]   [-0.401498380138]
# 6                                            Age  [-0.0336794741161]
# 7                                          SibSp   [-0.107209235064]
# 8                                          Parch   [-0.148723642487]

# %%
coefDf = pd.DataFrame(list(zip(X.columns, np.transpose(logregCV.coef_))))
#print 'Model Coefficients: \n', 
coefDf
# Out:
#                                                0                    1
# 0                                      Intercept  [1.33639602393e-05]
# 1  C(Sex, Treatment(reference='male'))[T.female]      [1.20010256636]
# 2                                 C(Pclass)[T.2]   [-0.0462712869403]
# 3                                 C(Pclass)[T.3]    [-0.893595609186]
# 4                               C(Embarked)[T.Q]     [-0.10553772369]
# 5                               C(Embarked)[T.S]      [-0.2730363809]
# 6                                            Age    [-0.017312439108]
# 7                                          SibSp   [-0.0495760020069]
# 8                                          Parch    [0.0171223177237]

# %%
logreg_coeffs = pd.DataFrame(logreg.coef_, columns=X.columns)
logreg_coeffs_t = coeffs.transpose()
logreg_coeffs_t.columns =['logistic coeffs']
logreg_coeffs_t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0488e770d046> in <module>()
#       1 logreg_coeffs = pd.DataFrame(logreg.coef_, columns=X.columns)
# ----> 2 logreg_coeffs_t = coeffs.transpose()
#       3 logreg_coeffs_t.columns =['logistic coeffs']
#       4 logreg_coeffs_t
#
# NameError: name 'coeffs' is not defined

# %%
logreg_coeffs_t.sort_values('logistic coeffs').plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1d97df932c6c> in <module>()
# ----> 1 logreg_coeffs_t.sort_values('logistic coeffs').plot(kind='bar')
#
# NameError: name 'logreg_coeffs_t' is not defined

# %%
logregCV_coeffs = pd.DataFrame(logregCV.coef_, columns=X.columns)
logregCV_coeffs_t = coeffs.transpose()
logregCV_coeffs_t.columns =['logistic coeffs']
logregCV_coeffs_t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-8fc08630ef4b> in <module>()
#       1 logregCV_coeffs = pd.DataFrame(logregCV.coef_, columns=X.columns)
# ----> 2 logregCV_coeffs_t = coeffs.transpose()
#       3 logregCV_coeffs_t.columns =['logistic coeffs']
#       4 logregCV_coeffs_t
#
# NameError: name 'coeffs' is not defined

# %%
logregCV_coeffs_t.sort_values('logistic coeffs').plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2c7e92409afe> in <module>()
# ----> 1 logregCV_coeffs_t.sort_values('logistic coeffs').plot(kind='bar')
#
# NameError: name 'logregCV_coeffs_t' is not defined

# %%
for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(logreg, X, y_ravel, scoring=metric)
    print(metric, scores.mean(), scores.std())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c7ac0fc9dc7f> in <module>()
#       1 for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
# ----> 2     scores = cross_val_score(logreg, X, y_ravel, scoring=metric)
#       3     print(metric, scores.mean(), scores.std())
#
# NameError: name 'cross_val_score' is not defined

# %%
for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(logregCV, X, y_ravel, cv=10, scoring=metric)
    print(metric, scores.mean(), scores.std())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9af13f4951e6> in <module>()
#       1 for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
# ----> 2     scores = cross_val_score(logregCV, X, y_ravel, cv=10, scoring=metric)
#       3     print(metric, scores.mean(), scores.std())
#
# NameError: name 'cross_val_score' is not defined

# %%
y_ravel = y.values.ravel()

model = LogisticRegression(penalty = 'l1', C=1.0)

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(model, X, y, cv=3, scoring=metric)
    print(metric, scores.mean(), scores.std())

print()    
model = LogisticRegression(penalty = 'l2', C=1.0)

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(model, X, y, cv=3, scoring=metric)
    print(metric, scores.mean(), scores.std())
    
print()
model = LogisticRegression(penalty = 'l1', C=0.1)

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(model, X, y, cv=3, scoring=metric)
    print(metric, scores.mean(), scores.std())
# Out:
# ('accuracy', 0.79639867139867138, 0.0017754494390683714)
# ('precision', 0.76270268185937107, 0.022243897644919221)
# ('recall', 0.6823474615742896, 0.04337381174409994)
# ('roc_auc', 0.84804540810252182, 0.010130660705031986)
# ()
# ('accuracy', 0.79639867139867138, 0.0017754494390683714)
# ('precision', 0.76270268185937107, 0.022243897644919221)
# ('recall', 0.6823474615742896, 0.04337381174409994)
# ('roc_auc', 0.84824350719958019, 0.011180863656742666)
# ()
# ('accuracy', 0.79751721418388088, 0.0097147362513174892)
# ('precision', 0.77426739926739918, 0.012661450031719245)
# ('recall', 0.66470009832841692, 0.036154918998722203)
# ('roc_auc', 0.84269326822221835, 0.010907366371209705)

# %% [markdown]
# #### What do the classification metrics tell us?

# %% [markdown]
# #### What does the Confusion Matrix tell us?

# %%
# plot and explain the ROC curve
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
# %matplotlib inline


Y_score = logreg.decision_function(Xte)

FPR = dict()
TPR = dict()
ROC_AUC = dict()

# For class 1, find the area under the curve
FPR[1], TPR[1], _ = roc_curve(yte, Y_score)
ROC_AUC[1] = auc(FPR[1], TPR[1])

# Plot of a ROC curve for class 1 (has_cancer)
plt.figure(figsize=[11,9])
plt.plot(FPR[1], TPR[1], label='ROC curve (area = %0.2f)' % ROC_AUC[1], linewidth=4)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Receiver operating characteristic for cancer detection', fontsize=18)
plt.legend(loc="lower right")
plt.show()

# %%
# plot and explain the ROC curve
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
# %matplotlib inline


Y_score = logregCV.decision_function(Xte)

FPR = dict()
TPR = dict()
ROC_AUC = dict()

# For class 1, find the area under the curve
FPR[1], TPR[1], _ = roc_curve(yte, Y_score)
ROC_AUC[1] = auc(FPR[1], TPR[1])

# Plot of a ROC curve for class 1 (has_cancer)
plt.figure(figsize=[11,9])
plt.plot(FPR[1], TPR[1], label='ROC curve (area = %0.2f)' % ROC_AUC[1], linewidth=4)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Receiver operating characteristic for cancer detection', fontsize=18)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Part 5: Gridsearch
# Use GridSearchCV with logistic regression to search for optimal parameters.

# %%
# parameter dict
from sklearn.grid_search import GridSearchCV
model2 = GridSearchCV(LogisticRegressionCV(solver='liblinear'), {'Cs':np.arange(2,12,1), 'cv':np.arange(2,17,1), 'penalty':['l1','l2']}, verbose=True)
model2.fit(Xtr, ytr)
# Out:
# --------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# <ipython-input-20-360e5269904e> in <module>()
#       2 from sklearn.grid_search import GridSearchCV
#       3 model2 = GridSearchCV(LogisticRegressionCV(solver='liblinear'), {'Cs':np.arange(2,12,1), 'cv':np.arange(2,17,1), 'penalty':['l1','l2']}, verbose=True)
# ----> 4 model2.fit(Xtr, ytr)
#
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     802
#     803         """
# --> 804         return self._fit(X, y, ParameterGrid(self.param_grid))
#     805
#     806
#
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     530                                  'of samples (%i) than data (X: %i samples)'
#     531                                  % (len(y), n_samples))
# --> 532         cv = check_cv(cv, X, y, classifier=is_classifier(estimator))
#     533
#     534         if self.verbose > 0:
#
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/cross_validation.pyc in check_cv(cv, X, y, classifier)
#    1675         if classifier:
#    1676             if type_of_target(y) in ['binary', 'multiclass']:
# -> 1677                 cv = StratifiedKFold(y, cv)
#    1678             else:
#    1679                 cv = KFold(_num_samples(y), cv)
#
# //anaconda/envs/py27/lib/python2.7/site-packages/sklearn/cross_validation.pyc in __init__(self, y, n_folds, shuffle, random_state)
#     531         for test_fold_idx, per_label_splits in enumerate(zip(*per_label_cvs)):
#     532             for label, (_, test_split) in zip(unique_labels, per_label_splits):
# --> 533                 label_test_folds = test_folds[y == label]
#     534                 # the test split can be too big because we used
#     535                 # KFold(max(c, self.n_folds), self.n_folds) instead of
#
# IndexError: too many indices for array

# %%
model2.best_params_

# %%
model2.best_score_

# %%
# print best parameters and score; is it better than original model?

# %%
# compute difference between L1 (Lasso) and L2 (Ridge) penalties on model coefficients

# %% [markdown]
# #### BONUS: Thresholds
# You decide that you want to minimize false positives. Use the predicted probabilities from the model to set your threshold for labeling the positive class to need at least 90% confidence. How and why does this affect your confusion matrix?

# %% [markdown]
# ## Part 6: Gridsearch and kNN
# Perform Gridsearch for the same classification problem as above, but use KNeighborsClassifier as your estimator, and number of neighbors and weights as test parameters.

# %%
# print best parameters and score; is it better than original model?

# %% [markdown]
# How does the number of neighbors affect the bias-variance tradeoff of your model? In what hypothetical scenarios might you prefer logistic regression over kNN, aside from model performance metrics?

# %%
# new kNN model with the optimal parameters

# %%
# new confusion matrix; what has changed?

# %%
# compare ROC curve between optimized models on same plot

# %% [markdown]
# #### BONUS: Average Precision
# Gridsearch the same parameters for logit but change scoring to 'average_precision' (optimizes parameters for area under the precision-recall curve instead of accuracy). Examine the best parameters, score, and confusion matrix. Are they different than the logistic regression gridsearch in part 5?

# %% [markdown]
# Plot the precision-recall curve. What does this tell us as opposed to the ROC curve?

# %% [markdown]
# #### BONUS: Decision Trees
# Gridsearch a decision tree classifier model on the data, searching for optimal depth. Create a new decision tree model with the optimal parameters. Compare the performace of the decision tree model to the logistic regression and kNN models.

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=1, max_depth=4)
model.fit(Xtr, ytr)
y_pred = model.predict(Xte)

# %%
from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
import pydotplus
dot_data = StringIO()  
export_graphviz(model, out_file=dot_data,  
                feature_names=X.columns,  
                filled=True, rounded=True,  
                special_characters=True)  

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_jpg())

# %%
model.classes_
# Out:
# array([ 0.,  1.])

# %%
print X.columns
print model.feature_importances_
# Out:
# Index([u'Intercept', u'C(Sex, Treatment(reference='male'))[T.female]',
#        u'C(Pclass)[T.2]', u'C(Pclass)[T.3]', u'C(Embarked)[T.Q]',
#        u'C(Embarked)[T.S]', u'Age', u'SibSp', u'Parch'],
#       dtype='object')
# [ 0.          0.63414405  0.03439792  0.15421686  0.03559628  0.
#   0.12545963  0.01618525  0.        ]

# %%
print classification_report(yte, y_pred, target_names=target_names)
# Out:
#              precision    recall  f1-score   support
#
#        dead       0.75      0.96      0.85       165
#    survived       0.89      0.49      0.63       102
#
# avg / total       0.81      0.78      0.76       267

# %% [markdown]
# >Note: tie the data and 'disaster' theme to a specific problem statement and hypothesis. Use Tableau to tell the story where it makes most sense in your report.

# %% [markdown]
# Score | /30
# ------|--------
# Executive Summary |
# Posgres, SQL, Cleaning|
# Risks and Assumptions |
# Data Dictionary |
# EDA |
# Tableau Storyboard|
# Logit Model |
# Logit Metrics|
# Gridsearch |
# kNN |
# Bonus: Thresholds |
# Bonus: Average Precision|
# Bonus: Decision Trees|

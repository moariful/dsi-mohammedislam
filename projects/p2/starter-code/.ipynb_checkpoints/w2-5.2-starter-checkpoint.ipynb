# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Read in billboard.csv as a data frame
bd_original = pd.read_csv("../assets/billboard.csv")
bd_original
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
bd_original.ix[:,7:].notnull().sum(axis=1)
# Out:
# 0      28
# 1      26
# 2      33
# 3      24
# 4      21
# 5      24
# 6      32
# 7      20
# 8      26
# 9      55
# 10     25
# 11     24
# 12     41
# 13     47
# 14     32
# 15     39
# 16     20
# 17     53
# 18     30
# 19     28
# 20     37
# 21     32
# 22     20
# 23     32
# 24     53
# 25     28
# 26     22
# 27     28
# 28     44
# 29     32
#        ..
# 287     3
# 288    20
# 289     5
# 290    18
# 291     3
# 292     9
# 293     6
# 294     5
# 295    12
# 296     6
# 297     7
# 298     4
# 299     4
# 300     8
# 301     3
# 302     4
# 303     7
# 304     5
# 305     5
# 306     3
# 307     3
# 308     3
# 309     2
# 310     2
# 311     1
# 312     1
# 313     4
# 314     2
# 315     2
# 316     1
# dtype: int64

# %%
# The simplest pivot table must have a dataframe and an 
# index. Let’s use the artist as our index.
pd.pivot_table(bd_original, index='artist.inverted')
# Out:
#                       x10th.week  x11th.week  x12th.week  x13th.week  \
# artist.inverted
# 2 Pac                        NaN         NaN         NaN         NaN
# 2Ge+her                      NaN         NaN         NaN         NaN
# 3 Doors Down           56.000000   56.000000   55.000000   54.000000
# 504 Boyz               57.000000   64.000000   70.000000   75.000000
# 98�                     6.000000    7.000000   22.000000   29.000000
# A*Teens                      NaN         NaN         NaN         NaN
# Aaliyah                23.000000   23.000000   22.500000   22.000000
# Adams, Yolanda         59.000000   66.000000   68.000000   61.000000
# Adkins, Trace          83.000000   92.000000         NaN         NaN
# Aguilera, Christina    10.000000    6.666667    2.333333    2.333333
# Alice Deejay           30.000000   36.000000   37.000000   39.000000
# Allan, Gary                  NaN         NaN         NaN         NaN
# ...

# %%
# Let's look at the data by artist and track. 
df2 = pd.pivot_table(bd_original, index=['artist.inverted', 'track'])

# %%
df2
# Out:
#                                                                          x10th.week  \
# artist.inverted      track
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                        NaN
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac...         NaN
# 3 Doors Down         Kryptonite                                                51.0
#                      Loser                                                     61.0
# 504 Boyz             Wobble Wobble                                             57.0
# 98�                  Give Me Just One Night (Una Noche)                         6.0
# A*Teens              Dancing Queen                                              NaN
# Aaliyah              I Don't Wanna                                             36.0
#                      Try Again                                                 10.0
# Adams, Yolanda       Open My Heart                                             59.0
# ...

# %%
# find out the number of weeks each song has been on the billboard
df3 = pd.melt(bd_original, id_vars=['artist.inverted', 'track'], value_vars=list(bd_original.iloc[:, 7:]))
df3
# Out:
#            artist.inverted                                              track  \
# 0          Destiny's Child                           Independent Women Part I
# 1                  Santana                                       Maria, Maria
# 2            Savage Garden                                 I Knew I Loved You
# 3                  Madonna                                              Music
# 4      Aguilera, Christina              Come On Over Baby (All I Want Is You)
# 5                    Janet                              Doesn't Really Matter
# 6          Destiny's Child                                        Say My Name
# 7        Iglesias, Enrique                                        Be With You
# 8                    Sisqo                                         Incomplete
# 9                 Lonestar                                             Amazed
# 10                  N'Sync                                   It's Gonna Be Me
# ...

# %%
df4 = pd.pivot_table(df3, index='track', aggfunc='count')

# %%
df4
# Out:
#                                      artist.inverted  value  variable
# track
# (Hot S**t) Country Grammar                        76     34        76
# 3 Little Words                                    76      9        76
# 911                                               76     19        76
# A Country Boy Can Survive                         76      3        76
# A Little Gasoline                                 76      6        76
# A Puro Dolor (Purest Of Pain)                     76     26        76
# Aaron's Party (Come Get It)                       76     15        76
# Absolutely (Story Of A Girl)                      76     27        76
# All Good?                                         76      3        76
# All The Small Things                              76     23        76
# Amazed                                            76     55        76
# American Pie                                      76      9        76
# ...

# %%
# add this as a new column
bd_original['weeks_on_chart']

# %%
# make a new df with just weeks on billboard, artist, and track
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
import numpy as np
import scipy as sp
from scipy import stats
import seaborn as sns
# %matplotlib inline

# %%
one_sample_data = [177.3, 182.7, 169.6, 176.3, 180.3, 179.4, 178.5, 177.2, 181.8, 176.5]

# %%
one_sample_data2 = [177.3, 182.7, 169.6, 176.3, 180.3, 179.4, 178.5, 177.2, 181.8, 176.5]

# %%
np.mean(one_sample_data)
# Out:
# 177.96000000000001

# %%
one_sample = stats.ttest_1samp(one_sample_data, 175.3)
print "The t-statistic is %.3f and the p-value is %.3f." % one_sample
# Out:
# The t-statistic is 2.296 and the p-value is 0.047.

# %%
paired_sample = stats.(one_sample_data, 175.3)

# %%
sns.distplot(one_sample_data)

# %%
import pandas as pd
import scipy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
import seaborn as sns
from datetime import datetime
# %matplotlib inline

# %%
from datetime import datetime

# %%
data = {'date': ['2014-05-01 18:47:05.069722', '2014-05-01 18:47:05.119994',
'2014-05-02 10:47:05.178768', '2014-05-02 18:47:05.230071',
'2014-05-02 15:47:05.230071', '2014-05-02 18:47:05.280592',
'2014-05-23 06:47:05.332662', '2014-05-03 18:47:05.385109',
'2014-05-14 00:47:05.436523', '2014-05-04 18:47:05.486877'],
        'battle_deaths': [34, 25, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data, columns = ['date', 'battle_deaths'])
print(df)
# Out:
#                          date  battle_deaths
# 0  2014-05-01 18:47:05.069722             34
# 1  2014-05-01 18:47:05.119994             25
# 2  2014-05-02 10:47:05.178768             26
# 3  2014-05-02 18:47:05.230071             15
# 4  2014-05-02 15:47:05.230071             15
# 5  2014-05-02 18:47:05.280592             14
# 6  2014-05-23 06:47:05.332662             26
# 7  2014-05-03 18:47:05.385109             25
# 8  2014-05-14 00:47:05.436523             62
# 9  2014-05-04 18:47:05.486877             41

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.index = df['date']
del df['date']
df.iloc
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722             34
# 2014-05-01 18:47:05.119994             25
# 2014-05-02 10:47:05.178768             26
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 15:47:05.230071             15
# 2014-05-02 18:47:05.280592             14
# 2014-05-23 06:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-14 00:47:05.436523             62
# 2014-05-04 18:47:05.486877             41

# %%
df.resample('H').sum()
# Out:
#                      battle_deaths
# date
# 2014-05-01 18:00:00           59.0
# 2014-05-01 19:00:00            NaN
# 2014-05-01 20:00:00            NaN
# 2014-05-01 21:00:00            NaN
# 2014-05-01 22:00:00            NaN
# 2014-05-01 23:00:00            NaN
# 2014-05-02 00:00:00            NaN
# 2014-05-02 01:00:00            NaN
# 2014-05-02 02:00:00            NaN
# 2014-05-02 03:00:00            NaN
# 2014-05-02 04:00:00            NaN
# 2014-05-02 05:00:00            NaN
# 2014-05-02 06:00:00            NaN
# 2014-05-02 07:00:00            NaN
# 2014-05-02 08:00:00            NaN
# 2014-05-02 09:00:00            NaN
# 2014-05-02 10:00:00           26.0
# 2014-05-02 11:00:00            NaN
# 2014-05-02 12:00:00            NaN
# 2014-05-02 13:00:00            NaN
# 2014-05-02 14:00:00            NaN
# 2014-05-02 15:00:00           15.0
# 2014-05-02 16:00:00            NaN
# 2014-05-02 17:00:00            NaN
# 2014-05-02 18:00:00           29.0
# ...

# %%
df.resample('H').sum().plot()
